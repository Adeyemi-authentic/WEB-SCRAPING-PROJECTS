# %%
from bs4 import BeautifulSoup
import requests

# %%
url='https://nkiri.com/tv-series-list/'

page=requests.get(url)

soup=BeautifulSoup(page.content,'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="html" lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- This site is optimized with the Yoast SEO plugin v22.2 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>TV Series List - Nkiri</title>
# <link href="https://nkiri.com/tv-series-list/" rel="canonical">
# <meta content="en_US" property="og:locale">
# <meta content="article" property="og:type"/>
# <meta content="TV Series List - Nkiri" property="og:title"/>
# ...

# %%
div=soup.find(class_='site-main clr')
div
# Out:
# <main class="site-main clr" id="main" role="main">
# <div class="container clr" id="content-wrap">
# <div class="content-area clr" id="primary">
# <div class="site-content clr" id="content">
# <article class="single-page-article clr">
# <div class="entry clr" itemprop="text">
# <div class="nkiri-before-content_24" id="nkiri-568406657"><script>(function(s,u,z,p){s.src=u,s.setAttribute('data-zone',z),p.appendChild(s);})(document.createElement('script'),'https://arvigorothan.com/tag.min.js',6136982,document.body||document.documentElement)</script></div> <div class="elementor elementor-29882" data-elementor-id="29882" data-elementor-type="wp-page">
# <section class="elementor-section elementor-top-section elementor-element elementor-element-a501a54 elementor-section-boxed elementor-section-height-default elementor-section-height-default" data-element_type="section" data-id="a501a54">
# <div class="elementor-container elementor-column-gap-default">
# ...

# %%
articles=div.find_all('article',class_="eael-grid-post eael-post-grid-column")
articles
# Out:
# [<article class="eael-grid-post eael-post-grid-column" data-id="78047">
#  <div class="eael-grid-post-holder">
#  <div class="eael-grid-post-holder-inner"><div class="eael-entry-media"><div class="eael-entry-overlay fade-in"><i aria-hidden="true" class="fas fa-long-arrow-alt-right"></i><a href="https://nkiri.com/acapulco-s01-s02-complete-tv-series/"></a></div><div class="eael-entry-thumbnail eael-image-ratio">
#  <img alt="download acapulco hollywood series" class="attachment-medium size-medium wp-image-78055" decoding="async" fetchpriority="high" height="300" sizes="(max-width: 200px) 100vw, 200px" src="https://nkiri.com/wp-content/uploads/2022/12/acapulco-hollywood-series-200x300.jpg" srcset="https://nkiri.com/wp-content/uploads/2022/12/acapulco-hollywood-series-200x300.jpg 200w, https://nkiri.com/wp-content/uploads/2022/12/acapulco-hollywood-series.jpg 600w" width="200"/>
#  </div>
# ...

# %%
nkiri=[]
for i in range(1,3):
    
    url='https://nkiri.com/tv-series-list/'

    page=requests.get(url)

    soup=BeautifulSoup(page.content,'html.parser')
    
    div=soup.find(class_='site-main clr')

# %%
for article in articles:
    series_name=article.find('h6',class_="eael-entry-title").text
    #print(series_name)
    
    nkiri.append(series_name)

# %%
import pandas as pd

# %%
df=pd.DataFrame(nkiri,columns=['series_name'])
df
# Out:
#                                            series_name
# 0            Acapulco S01 & S02 (Complete) | TV Series
# 1        Acting Good S02 (Episode 5 Added) | TV Series
# 2    Adventure Time: Fionna & Cake S01 (Episode 1 -...
# 3    African Queens: Njinga (Episode 1-4 Added) | T...
# 4             Ahsoka S01 (Episode 8 Added) | TV Series
# ..                                                 ...
# 145  Dragon Age: Absolution S01 (Complete) | Anime ...
# 146   East New York S01 (Episode 21 Added) | TV Series
# 147                 Echo 3 S01 (Complete)  | TV Series
# 148                    Echo S01 (Complete) | TV Series
# 149          Elite S01 & S02 ( Complete )  | TV Series
#
# [150 rows x 1 columns]
