# %%
from bs4 import BeautifulSoup
import requests

# %%
url='https://en.wikipedia.org/wiki/2023%E2%80%9324_Premier_League'

page=requests.get(url)

soup=BeautifulSoup(page.text,'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-night-mode-clientpref-0 vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>2023–24 Premier League - Wikipedia</title>
# ...

# %%
table=soup.find_all('table')[2]
table
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Team
# </th>
# <th>Manager
# </th>
# <th>Captain
# </th>
# <th>Kit manufacturer
# </th>
# <th>Shirt sponsor (chest)
# </th>
# <th>Shirt sponsor (sleeve)
# </th></tr>
# <tr>
# <td>Arsenal
# </td>
# <td data-sort-value="Arteta, Mikel"><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><a href="/wiki/Spain" title="Spain"><img alt="Spain" class="mw-file-element" data-file-height="500" data-file-width="750" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/23px-Flag_of_Spain.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/35px-Flag_of_Spain.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/45px-Flag_of_Spain.svg.png 2x" width="23"/></a></span></span> <a href="/wiki/Mikel_Arteta" title="Mikel Arteta">Mikel Arteta</a>
# </td>
# ...

# %%
table.find_all('th')
# Out:
# [<th>Team
#  </th>,
#  <th>Manager
#  </th>,
#  <th>Captain
#  </th>,
#  <th>Kit manufacturer
#  </th>,
#  <th>Shirt sponsor (chest)
#  </th>,
#  <th>Shirt sponsor (sleeve)
#  </th>]

# %%
headers=table.find_all('th')
headers
# Out:
# [<th>Team
#  </th>,
#  <th>Manager
#  </th>,
#  <th>Captain
#  </th>,
#  <th>Kit manufacturer
#  </th>,
#  <th>Shirt sponsor (chest)
#  </th>,
#  <th>Shirt sponsor (sleeve)
#  </th>]

# %%
total_headers = [header.text.strip() for header in headers]

# %%
print(total_headers)
# Out:
# ['Team', 'Manager', 'Captain', 'Kit manufacturer', 'Shirt sponsor (chest)', 'Shirt sponsor (sleeve)']

# %%
import pandas as pd

# %%
df=pd.DataFrame(columns=total_headers)
df
# Out:
# Empty DataFrame
# Columns: [Team, Manager, Captain, Kit manufacturer, Shirt sponsor (chest), Shirt sponsor (sleeve)]
# Index: []

# %%
column_data=table.find_all('tr')
column_data
# Out:
# [<tr>
#  <th>Team
#  </th>
#  <th>Manager
#  </th>
#  <th>Captain
#  </th>
#  <th>Kit manufacturer
#  </th>
#  <th>Shirt sponsor (chest)
#  </th>
#  <th>Shirt sponsor (sleeve)
#  </th></tr>,
#  <tr>
#  <td>Arsenal
#  </td>
#  <td data-sort-value="Arteta, Mikel"><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><a href="/wiki/Spain" title="Spain"><img alt="Spain" class="mw-file-element" data-file-height="500" data-file-width="750" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/23px-Flag_of_Spain.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/35px-Flag_of_Spain.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/45px-Flag_of_Spain.svg.png 2x" width="23"/></a></span></span> <a href="/wiki/Mikel_Arteta" title="Mikel Arteta">Mikel Arteta</a>
#  </td>
# ...

# %%
for row in column_data[1:]:
    row_data=row.find_all('td')
    individual_row_data=[data.text.strip() for data in row_data]
    #print(individual_row_data)
    
    length=len(df)
    df.loc[length]=individual_row_data

# %%
df
# Out:
#                        Team              Manager                 Captain  \
# 0                   Arsenal         Mikel Arteta     Martin Ødegaard[28]
# 1               Aston Villa           Unai Emery         John McGinn[32]
# 2               Bournemouth        Andoni Iraola                Neto[36]
# 3                 Brentford         Thomas Frank  Christian Nørgaard[40]
# 4    Brighton & Hove Albion     Roberto De Zerbi          Lewis Dunk[44]
# 5                   Burnley      Vincent Kompany           Jack Cork[47]
# 6                   Chelsea  Mauricio Pochettino         Reece James[51]
# 7            Crystal Palace       Oliver Glasner           Joel Ward[55]
# 8                   Everton           Sean Dyche      Séamus Coleman[59]
# 9                    Fulham          Marco Silva         Tom Cairney[63]
# 10                Liverpool         Jürgen Klopp     Virgil van Dijk[67]
# 11               Luton Town          Rob Edwards         Tom Lockyer[71]
# ...

# %%
df.columns
# Out:
# Index(['Team', 'Manager', 'Captain', 'Kit manufacturer',
#        'Shirt sponsor (chest)', 'Shirt sponsor (sleeve)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Team                    20 non-null     object
#  1   Manager                 20 non-null     object
#  2   Captain                 20 non-null     object
#  3   Kit manufacturer        20 non-null     object
#  4   Shirt sponsor (chest)   20 non-null     object
#  5   Shirt sponsor (sleeve)  20 non-null     object
# dtypes: object(6)
# memory usage: 1.1+ KB

# %%
df.to_csv(r"C:\Users\USER\OneDrive\Documents\python webscraping\premierleague_team_sponsors.csv",index=False)

# %%
table2=soup.find_all('table')[4]
table2
# Out:
# <table class="wikitable" style="text-align:center;">
# <tbody><tr>
# <th scope="col" width="28"><abbr title="Position">Pos</abbr>
# </th>
# <th scope="col" width="190">Team
# </th>
# <th scope="col" width="28"><abbr title="Played">Pld</abbr>
# </th>
# <th scope="col" width="28"><abbr title="Won">W</abbr>
# </th>
# <th scope="col" width="28"><abbr title="Drawn">D</abbr>
# </th>
# <th scope="col" width="28"><abbr title="Lost">L</abbr>
# </th>
# <th scope="col" width="28"><abbr title="Goals for">GF</abbr>
# </th>
# <th scope="col" width="28"><abbr title="Goals against">GA</abbr>
# </th>
# <th scope="col" width="28"><abbr title="Goal difference">GD</abbr>
# </th>
# <th scope="col" width="28"><abbr title="Points">Pts</abbr>
# </th>
# <th scope="col">Qualification or relegation
# </th></tr>
# <tr>
# <td style="text-align: center;font-weight: normal;background-color:#BBF3BB;">1
# </td>
# ...

# %%
header_titles=table2.find_all('th')
header_titles
# Out:
# [<th scope="col" width="28"><abbr title="Position">Pos</abbr>
#  </th>,
#  <th scope="col" width="190">Team
#  </th>,
#  <th scope="col" width="28"><abbr title="Played">Pld</abbr>
#  </th>,
#  <th scope="col" width="28"><abbr title="Won">W</abbr>
#  </th>,
#  <th scope="col" width="28"><abbr title="Drawn">D</abbr>
#  </th>,
#  <th scope="col" width="28"><abbr title="Lost">L</abbr>
#  </th>,
#  <th scope="col" width="28"><abbr title="Goals for">GF</abbr>
#  </th>,
#  <th scope="col" width="28"><abbr title="Goals against">GA</abbr>
#  </th>,
#  <th scope="col" width="28"><abbr title="Goal difference">GD</abbr>
#  </th>,
#  <th scope="col" width="28"><abbr title="Points">Pts</abbr>
#  </th>,
#  <th scope="col">Qualification or relegation
#  </th>,
#  <th scope="row" style="text-align: left; white-space:nowrap;font-weight: normal;background-color:#BBF3BB;"><a href="/wiki/Arsenal_F.C." title="Arsenal F.C.">Arsenal</a>
#  </th>,
# ...

# %%
world_header_titles=[titles.text.strip() for titles in header_titles]

# %%
print(world_header_titles)
# Out:
# ['Pos', 'Team', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Qualification or relegation', 'Arsenal', 'Liverpool (Y)', 'Manchester City', 'Aston Villa', 'Tottenham Hotspur', 'Manchester United', 'West Ham United', 'Brighton & Hove Albion', 'Wolverhampton Wanderers', 'Newcastle United', 'Chelsea', 'Fulham', 'Bournemouth', 'Crystal Palace', 'Brentford', 'Everton', 'Luton Town', 'Nottingham Forest', 'Burnley', 'Sheffield United']

# %%
df=pd.DataFrame(columns=world_header_titles)
df
# Out:
# Empty DataFrame
# Columns: [Pos, Team, Pld, W, D, L, GF, GA, GD, Pts, Qualification or relegation, Arsenal, Liverpool (Y), Manchester City, Aston Villa, Tottenham Hotspur, Manchester United, West Ham United, Brighton & Hove Albion, Wolverhampton Wanderers, Newcastle United, Chelsea, Fulham, Bournemouth, Crystal Palace, Brentford, Everton, Luton Town, Nottingham Forest, Burnley, Sheffield United]
# Index: []
#
# [0 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['Pos', 'Team', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts',
#        'Qualification or relegation', 'Arsenal', 'Liverpool (Y)',
#        'Manchester City', 'Aston Villa', 'Tottenham Hotspur',
#        'Manchester United', 'West Ham United', 'Brighton & Hove Albion',
#        'Wolverhampton Wanderers', 'Newcastle United', 'Chelsea', 'Fulham',
#        'Bournemouth', 'Crystal Palace', 'Brentford', 'Everton', 'Luton Town',
#        'Nottingham Forest', 'Burnley', 'Sheffield United'],
#       dtype='object')

# %%
df=df.drop(columns=['Arsenal', 'Liverpool (Y)',
       'Manchester City', 'Aston Villa', 'Tottenham Hotspur',
       'Manchester United', 'West Ham United', 'Brighton & Hove Albion',
       'Wolverhampton Wanderers', 'Newcastle United', 'Chelsea', 'Fulham',
       'Bournemouth', 'Crystal Palace', 'Brentford', 'Everton', 'Luton Town',
       'Nottingham Forest', 'Burnley', 'Sheffield United'])

df
# Out:
# Empty DataFrame
# Columns: [Pos, Team, Pld, W, D, L, GF, GA, GD, Pts, Qualification or relegation]
# Index: []

# %%
df.columns
# Out:
# Index(['Pos', 'Team', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts',
#        'Qualification or relegation'],
#       dtype='object')

# %%
column_data=table2.find_all('tr')
column_data
# Out:
# [<tr>
#  <th scope="col" width="28"><abbr title="Position">Pos</abbr>
#  </th>
#  <th scope="col" width="190">Team
#  </th>
#  <th scope="col" width="28"><abbr title="Played">Pld</abbr>
#  </th>
#  <th scope="col" width="28"><abbr title="Won">W</abbr>
#  </th>
#  <th scope="col" width="28"><abbr title="Drawn">D</abbr>
#  </th>
#  <th scope="col" width="28"><abbr title="Lost">L</abbr>
#  </th>
#  <th scope="col" width="28"><abbr title="Goals for">GF</abbr>
#  </th>
#  <th scope="col" width="28"><abbr title="Goals against">GA</abbr>
#  </th>
#  <th scope="col" width="28"><abbr title="Goal difference">GD</abbr>
#  </th>
#  <th scope="col" width="28"><abbr title="Points">Pts</abbr>
#  </th>
#  <th scope="col">Qualification or relegation
#  </th></tr>,
#  <tr>
#  <td style="text-align: center;font-weight: normal;background-color:#BBF3BB;">1
#  </td>
# ...

# %%
for row in column_data[1:]:
    row_data=row.find_all('td')
    individual_row_data=[data.text.strip() for data in row_data]
    print(individual_row_data)
# Out:
# ['1', '28', '20', '4', '4', '70', '24', '+46', '64', 'Qualification for the Champions League league stage']
# ['2', '28', '19', '7', '2', '65', '26', '+39', '64']
# ['3', '28', '19', '6', '3', '63', '28', '+35', '63']
# ['4', '29', '17', '5', '7', '60', '42', '+18', '56']
# ['5', '28', '16', '5', '7', '59', '42', '+17', '53', 'Qualification for the Europa League league stage[a]']
# ['6', '28', '15', '2', '11', '39', '39', '0', '47', 'Qualification for the Conference League play-off round[b]']
# ['7', '29', '12', '8', '9', '46', '50', '−4', '44', '']
# ['8', '28', '11', '9', '8', '50', '44', '+6', '42']
# ['9', '28', '12', '5', '11', '42', '44', '−2', '41']
# ['10', '28', '12', '4', '12', '59', '48', '+11', '40']
# ['11', '27', '11', '6', '10', '47', '45', '+2', '39']
# ['12', '29', '11', '5', '13', '43', '44', '−1', '38']
# ['13', '28', '9', '8', '11', '41', '52', '−11', '35']
# ['14', '28', '7', '8', '13', '33', '48', '−15', '29']
# ...
